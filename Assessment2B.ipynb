# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
c1=pd.read_csv(r"C:\Users\USER\Desktop\Data science source\GUVI\college_1.csv")
c2=pd.read_csv(r"C:\Users\USER\Desktop\Data science source\GUVI\college_2.csv")
concatenated = pd.concat([c1, c2], axis="rows")

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
expectations = c1[c1["CodeKata Score"] > 15000]
expectations_df = pd.DataFrame(expectations)
expectations_df.to_csv('exceeded_expectations.csv', index=False)

expectations1 = c1[(c1["CodeKata Score"] > 10000) & (c1["CodeKata Score"] < 15000)]
expectations1_df = pd.DataFrame(expectations1)
expectations1_df.to_csv('reached_expectations.csv', index=False)

expectations2 = c1[(c1["CodeKata Score"] > 7000) & (c1["CodeKata Score"] < 10000)]
expectations2_df = pd.DataFrame(expectations2)
expectations2_df.to_csv('needs_improvement.csv', index=False)

expectations3 = c1[c1["CodeKata Score"] < 7000]
expectations3_df = pd.DataFrame(expectations3)
expectations3_df.to_csv('unsatisfactory.csv', index=False)

# %%
expectations = c2[c2["CodeKata Score"] > 15000]
expectations_df = pd.DataFrame(expectations)
expectations_df.to_csv('exceeded_expectations1.csv', index=False)

expectations1 = c2[(c2["CodeKata Score"] > 10000) & (c2["CodeKata Score"] < 15000)]
expectations1_df = pd.DataFrame(expectations1)
expectations1_df.to_csv('reached_expectations1.csv', index=False)

expectations2 = c2[(c2["CodeKata Score"] > 7000) & (c2["CodeKata Score"] < 10000)]
expectations2_df = pd.DataFrame(expectations2)
expectations2_df.to_csv('needs_improvement1.csv', index=False)

expectations3 = c2[c2["CodeKata Score"] < 7000]
expectations3_df = pd.DataFrame(expectations3)
expectations3_df.to_csv('unsatisfactory1.csv', index=False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
c1=pd.read_csv(r"C:\Users\USER\Desktop\Data science source\GUVI\college_1.csv")
c2=pd.read_csv(r"C:\Users\USER\Desktop\Data science source\GUVI\college_2.csv")
concatenated = pd.concat([c1, c2], axis="rows")
concatenated['avg_points'] = concatenated[["Previous Geekions", "CodeKata Score"]].mean(axis=1)

# %% [markdown]
# ###### No of students participated

# %%
total_count=c1["Name"].count() + c2["Name"].count()
print(total_count)

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
count_python = len(c1[(c1["python"] == 100)])
count_mysql = len(c1[(c1["mysql"] == 100)])
count_python_en = len(c2[(c2["python_en"] == 100)])
count_computational_thinking = len(c2[(c2["computational_thinking"] == 100)])
total_count=c1["Name"].count() + c2["Name"].count()
avrg=(count_python+count_mysql+count_python_en+count_computational_thinking)/total_count
print(avrg)

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
top_three=concatenated.iloc[concatenated["Rising"].argsort()[-3:]]
for i in top_three["Name"].values:
    print(i)

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
top_three=concatenated.iloc[concatenated["CodeKata Score"].argsort()[-3:]]
for i in top_three["Name"].values:
    print(i)

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
dept_data = concatenated["Department"].unique()
score_data = []

for i in range(len(dept_data)):
    val=concatenated[concatenated.Department == dept_data[i]].sum()["CodeKata Score"]
    score_data.append(val)

plt.pie(score_data, labels=dept_data,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Department wise codekata performence")
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
dept_data = concatenated["Department"].unique()
topper_data = []

for i in range(len(dept_data)):
    val=concatenated[concatenated.Department == dept_data[i]].max()["Name"]
    topper_data.append(val)

# %%
dept = dept_data
topper = topper_data
x_pos=np.arange(len(topper))

plt.bar(x=x_pos, height = dept)
plt.xticks(x_pos,topper)
plt.show()
